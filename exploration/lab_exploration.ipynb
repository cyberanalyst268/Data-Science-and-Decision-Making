# %% [markdown]
# <a href="https://colab.research.google.com/github/cyberanalyst268/Data-Science-and-Decision-Making/blob/main/exploration/lab_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.datasets import load_wine

from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_blobs

# %% [markdown]
# * We have loaded the necessary libraries above
# * Now let's load the data

# %%
data = load_wine(as_frame=True)
df = data.data.copy()  # features
# Look at the documentation (https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_wine.html)
# and save the label in a column called 'y' in df.
df['y'] = data.target.copy()## YOUR CODE HERE # label
df.head()
# Out:
#    alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  y
# 0    14.23        1.71  2.43  ...                          3.92   1065.0  0
# 1    13.20        1.78  2.14  ...                          3.40   1050.0  0
# 2    13.16        2.36  2.67  ...                          3.17   1185.0  0
# 3    14.37        1.95  2.50  ...                          3.45   1480.0  0
# 4    13.24        2.59  2.87  ...                          2.93    735.0  0
#
# [5 rows x 14 columns]

# %%
#How many samples and features are there?

# YOUR CODE HERE
print('number of samples:', len(df), 'number of features:', len(df.columns) - 1)
# Out:
# number of samples: 178 number of features: 13

# %%
# Quiz Q1
# How many instances are there for each class? 

df['y'].value_counts()
# YOUR CODE HERE
# Out:
# 1    71
# 0    59
# 2    48
# Name: y, dtype: int64

# %%
# Calculate the means, medians, and standard deviations of each feature

df.iloc[:, :-1].describe()
# YOUR CODE HERE
# Out:
#           alcohol  malic_acid  ...  od280/od315_of_diluted_wines      proline
# count  178.000000  178.000000  ...                    178.000000   178.000000
# mean    13.000618    2.336348  ...                      2.611685   746.893258
# std      0.811827    1.117146  ...                      0.709990   314.907474
# min     11.030000    0.740000  ...                      1.270000   278.000000
# 25%     12.362500    1.602500  ...                      1.937500   500.500000
# 50%     13.050000    1.865000  ...                      2.780000   673.500000
# 75%     13.677500    3.082500  ...                      3.170000   985.000000
# max     14.830000    5.800000  ...                      4.000000  1680.000000
#
# [8 rows x 13 columns]

# %%
# Plot a boxplot of each feature (NOT THE LABEL!!) (all in one plot -- you can do this with a single line of code).
# Quiz Q2: Is there any feature that is in a clearly different scale than the others?

# YOUR CODE HERE
df.boxplot(grid=True, rot=50, fontsize=12)

# %%
# Let's look at the distributions of values of our features. Draw a histogram for each of the features

# YOUR CODE HERE
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f013fed8350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fe8ebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013febffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fe80550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f013fe3ab10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fdf2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fdb64d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fd6d850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f013fd6d890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fd1ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fc99810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fc4ed10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f013fc0f2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fc47790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fc00c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f013fbc2190>]],
#       dtype=object)

# %% [markdown]
# Let's do some multivariate analysis

# %%
from numpy.lib.function_base import corrcoef
# Calculate the correlations between each pair of variables

# YOUR CODE HERE
np.corrcoef(df)

# Plot a heatmap of the correlations between pairs of FEATURES (i.e., don't include the target!)

# YOUR CODE HERE
sns.heatmap(df.corr());

# %%
# What is the highest correlation between features?
dfx = df.drop(['y'],axis=1)
corr = dfx.corr()
kot = corr[corr>=.6]
plt.figure(figsize=(12,8))
sns.heatmap(kot, cmap="Reds")

# %% [markdown]
# You should have noticed that some of the features are highly correlated.
#
# For this reason, we can run into trouble when trying to train a classifier due to multicolinearity.
#
# Let's do PCA on this dataset to remove these correlations

# %%
# Let's do PCA:

# HINT: I suggest you attempt Q5 of the quiz and then use the function you developed
#       in this and some of the following cells.

# 1. Standardise your data using a StandardScaler. Make sure you're not scaling the 'y'!

# YOUR CODE HERE
scaler = StandardScaler()
scaler_result = scaler.fit_transform(dfx)
print(scaler_result)

# 2. Do PCA with 2 components. How much variance is retained from the original dataset?

# YOUR CODE HERE
pca = PCA(n_components=2, svd_solver='full')
pca_result = pca.fit_transform(scaler_result)
print(pca_result)
# Out:
# [[ 1.51861254 -0.5622498   0.23205254 ...  0.36217728  1.84791957
#    1.01300893]
#  [ 0.24628963 -0.49941338 -0.82799632 ...  0.40605066  1.1134493
#    0.96524152]
#  [ 0.19687903  0.02123125  1.10933436 ...  0.31830389  0.78858745
#    1.39514818]
#  ...
#  [ 0.33275817  1.74474449 -0.38935541 ... -1.61212515 -1.48544548
#    0.28057537]
#  [ 0.20923168  0.22769377  0.01273209 ... -1.56825176 -1.40069891
#    0.29649784]
#  [ 1.39508604  1.58316512  1.36520822 ... -1.52437837 -1.42894777
#   -0.59516041]]
# [[ 3.31675081 -1.44346263]
#  [ 2.20946492  0.33339289]
#  [ 2.51674015 -1.0311513 ]
#  [ 3.75706561 -2.75637191]
#  [ 1.00890849 -0.86983082]
#  [ 3.05025392 -2.12240111]
#  [ 2.44908967 -1.17485013]
#  [ 2.05943687 -1.60896307]
#  [ 2.5108743  -0.91807096]
#  [ 2.75362819 -0.78943767]
#  [ 3.47973668 -1.30233324]
#  [ 1.7547529  -0.61197723]
#  [ 2.11346234 -0.67570634]
#  [ 3.45815682 -1.13062988]
#  [ 4.31278391 -2.09597558]
#  [ 2.3051882  -1.66255173]
#  [ 2.17195527 -2.32730534]
#  [ 1.89897118 -1.63136888]
#  [ 3.54198508 -2.51834367]
#  [ 2.0845222  -1.06113799]
#  [ 3.12440254 -0.78689711]
#  [ 1.08657007 -0.24174355]
#  [ 2.53522408  0.09184062]
#  [ 1.64498834  0.51627893]
#  [ 1.76157587  0.31714893]
#  [ 0.9900791  -0.94066734]
#  [ 1.77527763 -0.68617513]
#  [ 1.23542396  0.08980704]
#  [ 2.18840633 -0.68956962]
#  [ 2.25610898 -0.19146194]
#  [ 2.50022003 -1.24083383]
#  [ 2.67741105 -1.47187365]
#  [ 1.62857912 -0.05270445]
#  [ 1.90269086 -1.63306043]
#  [ 1.41038853 -0.69793432]
#  [ 1.90382623 -0.17671095]
#  [ 1.38486223 -0.65863985]
#  [ 1.12220741 -0.11410976]
#  [ 1.5021945   0.76943201]
#  [ 2.52980109 -1.80300198]
#  [ 2.58809543 -0.7796163 ]
#  [ 0.66848199 -0.16996094]
#  [ 3.07080699 -1.15591896]
#  [ 0.46220914 -0.33074213]
#  [ 2.10135193  0.07100892]
#  [ 1.13616618 -1.77710739]
#  [ 2.72660096 -1.19133469]
#  [ 2.82133927 -0.6462586 ]
#  [ 2.00985085 -1.24702946]
#  [ 2.7074913  -1.75196741]
#  [ 3.21491747 -0.16699199]
#  [ 2.85895983 -0.7452788 ]
#  [ 3.50560436 -1.61273386]
#  [ 2.22479138 -1.875168  ]
#  [ 2.14698782 -1.01675154]
#  [ 2.46932948 -1.32900831]
#  [ 2.74151791 -1.43654878]
#  [ 2.17374092 -1.21219984]
#  [ 3.13938015 -1.73157912]
#  [-0.92858197  3.07348616]
#  [-1.54248014  1.38144351]
#  [-1.83624976  0.82998412]
#  [ 0.03060683  1.26278614]
#  [ 2.05026161  1.9250326 ]
#  [-0.60968083  1.90805881]
#  [ 0.90022784  0.76391147]
#  [ 2.24850719  1.88459248]
#  [ 0.18338403  2.42714611]
#  [-0.81280503  0.22051399]
#  [ 1.9756205   1.40328323]
#  [-1.57221622  0.88498314]
#  [ 1.65768181  0.9567122 ]
#  [-0.72537239  1.0636454 ]
#  [ 2.56222717 -0.26019855]
#  [ 1.83256757  1.2878782 ]
#  [-2.4655558  -2.1937983 ]
#  [-3.37052415 -2.21628914]
#  [-2.60195585 -1.75722935]
#  [-2.67783946 -2.76089913]
#  [-2.38701709 -2.29734668]
#  [-3.20875816 -2.76891957]]

# %%
# Plot your two components, using the label from the data to colour the points

# YOUR CODE HERE
plt.scatter(scaler_result[:, 0], pca_result[:, 1], c=df['y'])

# %%
# How many components do you need to keep at least 85% of the variance in the dataset? (Q6)

# YOUR CODE HERE
covar_matrix = PCA(n_components = 20)
plt.ylabel('% Variance Explained')
plt.xlabel('# of Features')
plt.title('PCA Analysis')
plt.ylim(85)
plt.style.context('seaborn-whitegrid')


plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x7f01409c45d0>,
#  <matplotlib.lines.Line2D at 0x7f01409c4990>,
#  <matplotlib.lines.Line2D at 0x7f01409c4910>,
#  <matplotlib.lines.Line2D at 0x7f01409c4d90>,
#  <matplotlib.lines.Line2D at 0x7f0140c02e90>,
#  <matplotlib.lines.Line2D at 0x7f0140985a10>,
#  <matplotlib.lines.Line2D at 0x7f0140985e50>,
#  <matplotlib.lines.Line2D at 0x7f0140985790>,
#  <matplotlib.lines.Line2D at 0x7f01409c41d0>,
#  <matplotlib.lines.Line2D at 0x7f01415587d0>,
#  <matplotlib.lines.Line2D at 0x7f01409c4490>,
#  <matplotlib.lines.Line2D at 0x7f0140985d50>,
#  <matplotlib.lines.Line2D at 0x7f0140985450>,
#  <matplotlib.lines.Line2D at 0x7f01408e9a90>]

# %%
# How much variance is retained if we do PCA with 3 components? (Q7)

# YOUR CODE HERE
covar_matrix = PCA(n_components = 3)
plt.ylabel('% Variance Explained')
plt.xlabel('# of Features')
plt.title('PCA Analysis')
#plt.ylim(85)
plt.style.context('seaborn-whitegrid')


plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x7f0140ba12d0>,
#  <matplotlib.lines.Line2D at 0x7f0140bd4d10>,
#  <matplotlib.lines.Line2D at 0x7f0140d0d950>,
#  <matplotlib.lines.Line2D at 0x7f0140d0da10>,
#  <matplotlib.lines.Line2D at 0x7f0140d0d450>,
#  <matplotlib.lines.Line2D at 0x7f0140c44fd0>,
#  <matplotlib.lines.Line2D at 0x7f0140bc8cd0>,
#  <matplotlib.lines.Line2D at 0x7f0140b41e90>,
#  <matplotlib.lines.Line2D at 0x7f0140d0d690>,
#  <matplotlib.lines.Line2D at 0x7f0140d0d2d0>,
#  <matplotlib.lines.Line2D at 0x7f0140ba1f10>,
#  <matplotlib.lines.Line2D at 0x7f0140b41990>,
#  <matplotlib.lines.Line2D at 0x7f0140b41750>,
#  <matplotlib.lines.Line2D at 0x7f0140b41610>]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Let's see how many clusters does K-Means find.

# %%
# Use the elbow method to select the number of clusters in your data using 3 PCs.

# YOUR CODE HERE
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(dfx)
    distortions.append(kmeanModel.inertia_)
    plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
# Now use the silhouette score to choose between the two candidate k values from the previous cell

# YOUR CODE HERE
silhouette_score = (10-1)/max(1,10)

# %%
# Visualise the first two pcs (using a scatterplot) using the labels from KMeans with your chosen value of k

# YOUR CODE HERE
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# Now we can try to understand our clusters.

# %%
# In the original (before PCA and before standardisation) dataframe, add a column called 'cluster' that contains
# the cluster assignment from above

# YOUR CODE HERE
kmeans = KMeans(n_clusters=3)
y_predict = kmeans.fit_predict(pca_result)
df['cluster']=y_predict

# %%
# Do a boxplot of each feature, separating between clusters

# YOUR CODE HERE
for value in df['cluster'].unique():
  df.loc[df['cluster'] == value].boxplot(column = [col for col in df[0:16]],grid=False, rot=90, fontsize=12)
  plt.show()

# %% [markdown]
# Write your observations here.
# For example: is there a clear difference between the clusters in terms of alcohol content? What about flavanoids?

# %%
# Feel free to keep playing with the data here!
